# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

xvals = range(150)
yvals = range(100)

xcenter = 25
ycenter = 60

image = []

for j in yvals:
    line = []
    yv = (j-ycenter)
    for i in xvals:
        xv = (i-xcenter)
        line.append(sqrt(xv*xv + yv*yv))
    image.append(line)

# %%
fig, ax = plt.subplots(1,1, dpi=(120), subplot_kw={'aspect': 'equal'})
v = ax.imshow(image, origin = 'lower')
cbar =  fig.colorbar(v)
cbar.set_label('Radius')
ax.plot(xcenter, ycenter, 'wx', ms=3)
ax.text(xcenter, ycenter, 'Center', color ='w')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient')
# Out:
# Text(0.5, 1.0, 'Gradient')

# %%
x_n = [i for i in range(200)]
y_n = [j for j in range (200)]
x_center = 100
y_center = 80
image = [ np.sin((i-x_center)**2 + (j-y_center)**2) for j in y_n for i in x_n ]
image = np.array(image).reshape((len(x_n), len(y_n)))

# %%
fig, ax = plt.subplots(1,1, dpi=(120), subplot_kw={'aspect': 'equal'})
vals = ax.imshow(image, origin = 'lower')
cbar =  fig.colorbar(vals)
cbar.set_label('Radius')
#ax.plot(x_center, y_center, 'wx', ms=3)
#ax.text(x_center, y_center, 'Center', color ='w')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient')
plt.tight_layout()
